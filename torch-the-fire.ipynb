# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class VAE (nn.Module):
    def __init__ (self,input_dim,latent_dim):
        super(VAE.self).__init__()
        self.input_dim = input_dim
        slff.latent_dim = latent_dim
        
        self.encoder = nn.Sequential(
            nn.Linear(input_dim,32),
            nn.ReLU(),
            nn.Linear(32,64),
            nn.ReLU(),
            nn.Linear(64,128),
            nn.ReLU
        )
        
        self.mu = nn.Linear(128,latent_dim)
        self.log_var = nn.Linear(128,latent_dim)
        
        self.decoder = nn.sequential(
            nn.Linear(latent_dim,128),
            nn.ReLU(),
            nn.Linear(128,64),
            nn.ReLU(),
            nn.Linear(64,32),
            nn.ReLU(),
            nn.Linear(32,input_dim),
            nn.Sigmoid()
        )
        
    def encode(self,x):
        h = self.encoder(x)
        mu = self.mu(h)
        log_var = slef.log_var(h)
        
    ##tobe continued

# %%
## gradeint descent in numpy by chatGPT
import numpy as np

def linear_regression(x,b0,b1):
    return b0+b1*x

def cost_function(y_pred, y_true):
    n = len(y_pred)
    mse = (1/n)*np.sum((y_pred-y_true)**2)
    return mse

x = np.array([1, 2, 3, 4, 5])
y_true = np.array([2, 3, 4, 5, 6])

n = len(x)
b0 = 0
b1 = 1

alpha = 0.0001
it= 10000

for i in range(it):
    y_pred = linear_regression(x,b0,b1)
   
    #gradients calculation
    db0 = (2/n)*np.sum((y_pred,y_true))
    
    db1 = (2/n)*np.sum((y_pred,y_true)*x)
    
    #update model parameter
    b0 = b0 - alpha * db0
    b1 = b1 - alpha * db1

    
    cost = cost_function(y_pred, y_true)
    
    
    if i % 1000 == 0:
        print("{} Cost: {}, gradient {}, change: {}".format(i, cost,[db0,db1],[b0,b1]))
    
    
print("FINAL b0: {}, b1: {}".format(b0, b1))
# Out:
# 0 Cost: 1.0, gradient [14.0, 50.0], change: [-0.0014, 0.995]
# 1000 Cost: 60.37360932084402, gradient [1.432341753689751, 4.644866023039109], change: [-0.5448529288078829, -0.9135042961098407]
# 2000 Cost: 70.72334193712643, gradient [0.25226004034002475, 0.40189485413171155], change: [-0.6077312556677482, -1.0887615062075042]
# 3000 Cost: 71.7378341103965, gradient [0.13790361413039492, 0.005948394870628704], change: [-0.625240147655799, -1.101941206719626]
# 4000 Cost: 71.8371265781311, gradient [0.1234028819786019, -0.030049714919420014], change: [-0.6381171286574754, -1.1000615852423152]
# 5000 Cost: 71.85033083313608, gradient [0.11837245196258053, -0.0324007225384662], change: [-0.6501870524442518, -1.0968762795342977]
# 6000 Cost: 71.85539130237028, gradient [0.11435032997597645, -0.03163703658944428], change: [-0.6618202501569785, -1.0936688429256847]
# ...

# %%
tt= np.array([[1, 1], [2, 1], [3, 1], [4, 1], [5, 1]])
tt.T.T
# Out:
# array([[1, 1],
#        [2, 1],
#        [3, 1],
#        [4, 1],
#        [5, 1]])

# %%
#testing gaussian
import matplotlib.pyplot as plt
xx = np.random.normal(0,.01,size=(100000,1))
# plt.hist(xx)
plt.hist([11,3,-6,4-2,5,7])
# Out:
# (array([1., 0., 0., 0., 1., 1., 1., 1., 0., 1.]),
#  array([-6. , -4.3, -2.6, -0.9,  0.8,  2.5,  4.2,  5.9,  7.6,  9.3, 11. ]),
#  <BarContainer object of 10 artists>)

# %%
# import numpy as np
import pandas as pd
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression


# Generate data using make_regression
X, y = make_regression(n_samples=200, n_features=5, random_state=0)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Fit the PLS model
pls = PLSRegression(n_components=2)
pls.fit(X_train, y_train)

# Predict the response for the test data
y_pred = pls.predict(X_test)

# Calculate the mean squared error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Print the MSE
print("MSE:", mse)

# Print the PLS regression coefficients
print("PLS regression coefficients:", pls.coef_)

# Print the PLS explained variance ratio
print("PLS object:", vars(pls))
# Out:
# MSE: 8.312956731871584
# PLS regression coefficients: [[ 74.11662832]
#  [ 81.70201759]
#  [ 61.94166759]
#  [103.29985082]
#  [ 84.91362909]]
# PLS object: {'n_components': 2, 'deflation_mode': 'regression', 'mode': 'A', 'scale': True, 'algorithm': 'nipals', 'max_iter': 500, 'tol': 1e-06, 'copy': True, 'n_features_in_': 5, '_norm_y_weights': False, '_x_mean': array([-0.03423207, -0.10124173, -0.02799836, -0.04601649, -0.01912039]), '_y_mean': array([-19.07090216]), '_x_std': array([0.94086732, 1.01021319, 0.90716287, 1.0577945 , 0.96192974]), '_y_std': array([193.42854003]), 'x_weights_': array([[ 0.45685708, -0.55306902],
#        [ 0.44177015,  0.04275254],
#        [ 0.3614204 , -0.24711252],
#        [ 0.56115097,  0.02663157],
#        [ 0.38807941,  0.79404851]]), 'y_weights_': array([[0.93970107, 0.08980771]]), '_x_scores': array([[-0.14670024,  2.76086928],
#        [ 0.41492294,  0.37432112],
#        [ 1.79953179, -0.13208787],
#        [ 2.46543418, -0.06307142],
# ...
