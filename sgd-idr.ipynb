# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nilai-tukar-sgd-idr-2021-2022.csv')
dailydf = pd.read_csv('nilai-tukar-sgd-idr-2021-2022-daily.csv')

# %%
dailydf.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-01-01  10533.151367  10619.362305  10498.865234  10533.151367
# 1  2021-01-04  10517.348633  10559.720703  10501.367188  10517.507813
# 2  2021-01-05  10550.174805  10583.382813  10507.725586  10504.722656
# 3  2021-01-06  10572.413086  10595.149414  10534.453125  10546.136719
# 4  2021-01-07  10589.374023  10672.227539  10502.211914  10589.374023
#
#       Adj Close  Volume
# 0  10533.151367       0
# 1  10517.507813       0
# 2  10504.722656       0
# 3  10546.136719       0
# 4  10589.374023       0

# %%
plt.plot(df['Date'],df['Close'])
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(dailydf['Date'],dailydf['Close'])
plt.xticks(rotation=90)
plt.figure().set_figwidth(25)
# plt.figure(figsize=(20,20))
plt.show()
