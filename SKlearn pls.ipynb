# %%
from sklearn.cross_decomposition import PLSRegression
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=100, n_features=10, n_informative=5, random_state=2)
pls = PLSRegression(n_components=2)
pls.fit(X,y)

score=pls.score(X,y)
"the score of model ",score,'pls.coef_',pls.coef_,'y',y,y.shape,X.shape,'x weights', pls.x_weights_
# Out:
# ('the score of model ',
#  0.9989046513042084,
#  'pls.coef_',
#  array([[ 9.02944472],
#         [ 2.7899141 ],
#         [82.993956  ],
#         [-0.10647527],
#         [66.54450389],
#         [88.7568663 ],
#         [-0.17806464],
#         [73.92177051],
#         [ 0.15364384],
#         [-3.2208417 ]]),
#  'y',
#  array([-5.62927423e+01, -1.75407504e+02, -8.96573545e+00, -1.99631208e+02,
#          1.93404967e+02,  3.81531337e+01, -1.19445600e+02, -2.38458758e+01,
#         -2.29492626e+02,  1.78333768e+02,  3.41064247e+01,  2.32090310e+02,
#         -3.40678315e+01, -4.24931950e+01, -3.03652464e+01,  3.03894719e+01,
#         -9.66428758e+01, -1.28170168e+01,  4.07029001e+01, -2.34839478e+02,
#         -9.91578938e+01, -1.10016975e+02,  6.62987444e+00,  1.92062550e+02,
#          1.37757805e+02, -2.20770700e+02,  1.07381245e+02, -4.75655795e+00,
#          3.57600196e+01,  1.81742442e+02, -2.20525828e+01,  5.04870123e+01,
# ...

# %%
X_transformed = pls.transform(X)
X_transformed[0:20],X_transformed.shape,'original X',X[0:20], X.shape
# Out:
# (array([[-0.37260357,  0.02113665],
#         [-0.8048333 , -1.197357  ],
#         [ 0.20055575, -0.56550028],
#         [-1.000155  , -1.23107177],
#         [ 1.43843843, -0.12947179],
#         [ 0.8654017 , -1.90999351],
#         [-0.63371215, -0.45679879],
#         [-0.14740083,  0.07808693],
#         [-1.69557635,  0.89774657],
#         [ 1.27087259,  0.22549471],
#         [ 0.19748307,  0.45102047],
#         [ 1.35886388,  1.35336401],
#         [-0.14430752, -0.03235229],
#         [-0.36322982,  0.70053007],
#         [ 0.01783876, -0.54227743],
#         [ 0.13576802,  0.81183738],
#         [-0.2091517 , -1.65886153],
#         [-0.19343473,  0.68843972],
#         [ 0.53046206, -0.54091774],
#         [-1.87028519,  1.28100247]]),
#  (100, 2),
#  'original X',
#  array([[ 2.67964423e+00, -4.44454771e-01, -2.15424151e-01,
#           1.88960995e-01, -1.76855889e-01, -1.47462796e+00,
#           9.11747865e-01,  1.03691782e+00, -4.59134928e-01,
# ...
